# %%
# Load the overlay containing the IP
# AXILiteS
# 0x00 : reserved
# 0x04 : reserved
# 0x08 : reserved
# 0x0c : reserved
# 0x10 : Data signal of o_ov
#        bit 31~0 - o_ov[31:0] (Read)
# 0x14 : Data signal of o_ov
#        bit 31~0 - o_ov[63:32] (Read)
# 0x18 : Data signal of o_ov
#        bit 15~0 - o_ov[79:64] (Read)
#        others   - reserved
# 0x1c : Control signal of o_ov
#        bit 0  - o_ov_ap_vld (Read/COR)
#        others - reserved
# 0x20 : Data signal of o_ready
#        bit 0  - o_ready[0] (Read)
#        others - reserved
# 0x24 : Control signal of o_ready
#        bit 0  - o_ready_ap_vld (Read/COR)
#        others - reserved
# 0x28 : Data signal of o_Gc
#        bit 31~0 - o_Gc[31:0] (Read)
# 0x2c : Data signal of o_Gc
#        bit 31~0 - o_Gc[63:32] (Read)
# 0x30 : Data signal of o_Gc
#        bit 15~0 - o_Gc[79:64] (Read)
#        others   - reserved
# 0x34 : Control signal of o_Gc
#        bit 0  - o_Gc_ap_vld (Read/COR)
#        others - reserved
# 0x38 : Data signal of o_toSend01
#        bit 31~0 - o_toSend01[31:0] (Read)
# 0x3c : Data signal of o_toSend01
#        bit 31~0 - o_toSend01[63:32] (Read)
# 0x40 : Data signal of o_toSend01
#        bit 15~0 - o_toSend01[79:64] (Read)
#        others   - reserved
# 0x44 : Control signal of o_toSend01
#        bit 0  - o_toSend01_ap_vld (Read/COR)
#        others - reserved
# 0x48 : Data signal of o_toSend10
#        bit 31~0 - o_toSend10[31:0] (Read)
# 0x4c : Data signal of o_toSend10
#        bit 31~0 - o_toSend10[63:32] (Read)
# 0x50 : Data signal of o_toSend10
#        bit 15~0 - o_toSend10[79:64] (Read)
#        others   - reserved
# 0x54 : Control signal of o_toSend10
#        bit 0  - o_toSend10_ap_vld (Read/COR)
#        others - reserved
# 0x58 : Data signal of o_toSend11
#        bit 31~0 - o_toSend11[31:0] (Read)
# 0x5c : Data signal of o_toSend11
#        bit 31~0 - o_toSend11[63:32] (Read)
# 0x60 : Data signal of o_toSend11
#        bit 15~0 - o_toSend11[79:64] (Read)
#        others   - reserved
# 0x64 : Control signal of o_toSend11
#        bit 0  - o_toSend11_ap_vld (Read/COR)
#        others - reserved
# 0x68 : Data signal of i_iv
#        bit 0  - i_iv[0] (Read/Write)
#        others - reserved
# 0x6c : reserved
# 0x70 : Data signal of i_R
#        bit 31~0 - i_R[31:0] (Read/Write)
# 0x74 : Data signal of i_R
#        bit 31~0 - i_R[63:32] (Read/Write)
# 0x78 : Data signal of i_R
#        bit 15~0 - i_R[79:64] (Read/Write)
#        others   - reserved
# 0x7c : reserved
# 0x80 : Data signal of i_Ga
#        bit 31~0 - i_Ga[31:0] (Read/Write)
# 0x84 : Data signal of i_Ga
#        bit 31~0 - i_Ga[63:32] (Read/Write)
# 0x88 : Data signal of i_Ga
#        bit 15~0 - i_Ga[79:64] (Read/Write)
#        others   - reserved
# 0x8c : reserved
# 0x90 : Data signal of i_Gb
#        bit 31~0 - i_Gb[31:0] (Read/Write)
# 0x94 : Data signal of i_Gb
#        bit 31~0 - i_Gb[63:32] (Read/Write)
# 0x98 : Data signal of i_Gb
#        bit 15~0 - i_Gb[79:64] (Read/Write)
#        others   - reserved
# 0x9c : reserved
# 0xa0 : Data signal of i_gid
#        bit 31~0 - i_gid[31:0] (Read/Write)
# 0xa4 : Data signal of i_gid
#        bit 31~0 - i_gid[63:32] (Read/Write)
# 0xa8 : reserved

# example values for Ga, Gb,gid and R
# gid : 0
# R   : aad3360fdc9014b9f593
# 0,1 garbled values for left and right wire

# labelL[0]: 904f991b17861ec92b0c    labelL[1]: 3a9caf14cb160a70de9f
# labelR[0]: df4b7f9af539227bdcd8    labelR[1]: 7598499529a936c2294b

# val a: 904f991b17861ec92b0c
# val b: df4b7f9af539227bdcd8

#  outputlabels of the gate
#lb[0] :625e292a386cd9e5a14d    lb[1] : c88d1f25e4fccd5c54de

# gtt
# gtt[0][0] : 625e292a386cd9e5a14d
# gtt[0][1] : 625e292a386cd9e5a14d
# gtt[1][0] : 625e292a386cd9e5a14d
# gtt[1][1] : c88d1f25e4fccd5c54de
 
# ToSend values
# toSend00[0][0] : 00000000000000000000
# toSend01[0][1] : 53e82567bcb881eb8dff
# toSend10[1][0] : 4baafae24102d2b47a8a
# toSend11[1][1] : 194bae7f57e10f1b4cd1

from pynq import Overlay

overlay = Overlay('/home/xilinx/garble_and_overlay/garble_and_overlay.bit')

# %%
overlay?
